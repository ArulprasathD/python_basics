# %%
class car:             #----------> class name
                       #----------> attribute
    brand = "BMW"
    price = 5000000

k1 = car()             #-----------> object

print("BRAND :",k1.brand)
print("PRICE :",k1.price)
# Out:
# BRAND : BMW
# PRICE : 5000000
