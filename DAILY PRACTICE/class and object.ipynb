# %%
class car:             #----------> class name
                       #----------> attribute
    brand = "BMW"
    price = 5000000

k1 = car()             #-----------> object

print("BRAND :",k1.brand)
print("PRICE :",k1.price)
# Out:
# BRAND : BMW
# PRICE : 5000000

# %%
class student:
    name = "Arul"
    age = 20

call=student()
print(call.name)
print(call.age)
# Out:
# Arul
# 20

# %%
class car:
    def __init__ (self,brand,price):
        self.brand = brand
        self.price = price

c1 = car("BMW",50000000)

print(f"Brand : {c1.brand}")
print(f"Price : {c1.price}")
# Out:
# Brand : BMW
# Price : 50000000

# %% [raw]
# Name : Arul
# Balance : 1000
#
# Deposit : 500
# Balance : 1500
#
# Withdraw : 300
# Balance : 1200

# %%
class Bank:

    def __init__(self, name, amount):
        self.name = name
        self.amount = amount

    def deposit(self, deposit):
        self.amount = self.amount + deposit
        print("Balance after deposit :", self.amount)

    def withdrawal(self, withdrawal):
        self.amount = self.amount - withdrawal
        print("Balance after withdrawal :", self.amount)


name = input("Enter name : ")
amount = int(input("Enter Amount : "))

s1 = Bank(name, amount)

deposit = int(input("Enter deposit Amount : "))
s1.deposit(deposit)

withdrawal = int(input("Enter withdrawal Amount : "))
s1.withdrawal(withdrawal)
# Out:
# Enter name :  arul
# Enter Amount :  20000
# Enter deposit Amount :  500
# Balance after deposit : 20500
# Enter withdrawal Amount :  19000
# Balance after withdrawal : 1500

# %%
expenses = []

def add_expense():
    name = input("Expense name: ")
    amount = int(input("Amount: "))
    category = input("Category: ")
    expenses.append([name, amount, category])
    print("Added!")

def view_expenses():
    for e in expenses:
        print(e)

def total():
    print(sum(e[1] for e in expenses))

add_expense()
view_expenses()
total()
# Out:
# Expense name:  ee
# Amount:  22
# Category:  3e
# Added!
# ['ee', 22, '3e']
# 22
