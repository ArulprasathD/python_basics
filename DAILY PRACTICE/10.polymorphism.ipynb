# %%
class website:
    def show (self):
        print("BLUE ui")

class dashboard(website):
    def login(self):
        print("login page")

#    def show(self):                            #method overwriting
#        print("BLUE & GREEN ui")

call = dashboard()
call.login()
call.show()
# Out:
# login page
# BLUE ui

# %%
class laptop:
    def os(self):
        print("windows 10")

class update:
    def version(self):
        print("version : 25H2")

    def os(self):
        print("windows 11 pro")


call = update()
call.os()
call.version()
# Out:
# windows 11 pro
# version : 25H2
