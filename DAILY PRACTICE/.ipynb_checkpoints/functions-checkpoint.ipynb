# %%
def name(name):
    print(name)

name("arul")
name("arulll")
# Out:
# arul
# arulll

# %%
a1 = int(input("Enter number 1 : "))
b1 = int(input("Enter number 2 : "))

def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)

add(a = a1,b = b1)
sub(a = a1,b = b1)
# Out:
# Enter number 1 :  4
# Enter number 2 :  7
# 11
# -3
