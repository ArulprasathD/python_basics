# %%
class Student:             #creating class
    def __init__(self,name,age,mark):
        self.name = name
        self.age = age
        self.mark = mark


    def details(self):
        return self.name,self.age,self.mark
            
name = input("Enter name : ")
age = int(input("Enter age : "))
mark = int(input("Enter mark : "))

s1=Student(name,age,mark)
print(s1.details())

# %%
while True : print(eval(input("Enter 2 input >>>")))

# %%
class car:
    def __init__(self,brand,model,price):
        self.brand = brand
        self.model = model
        self.price = price

    def show_car_details(self):
        print("BRAND : ",self.brand)
        print("MODEL : ",self.model)
        print("PRICE : ",self.price)

brand = input("Enter car brand : ").upper()
model = int(input("Enter car model : "))
price = input("Enter the price : ")

c1 = car(brand,model,price)

print("\n output")
c1.show_car_details()
# Out:
# Enter car brand :  bmw
# Enter car model :  2020
# Enter the price :  200000
#  output
# BRAND :  BMW
# MODEL :  2020
# PRICE :  200000

# %% [raw]
# BankAccount class create pannu
# Balance private ah vechiko
# Deposit & withdraw methods create pannu
# Direct access block pannanu

# %%
class BankAccount:
    def __init__(self,bal):
        self.__bal = bal

    def __balance(self):
        return self.bal

    def deposit(self,deposit_amount):
        self.__bal = self.__bal + deposit_amount
        return deposit_amount

    def withdrawal(self,withdrawal_amount):
        #self.__balance += withdrawal_amount
        if withdrawal_amount <= self.__bal:
             self.__balance -= amount
            print("Withdrawn:", amount)
        else:
            print("Insufficient balance")
