# %% [markdown]
# # tuples

# %%
j = ("banana","apple","mango","orange")

print(j)
print(type(j))
# Out:
# ('banana', 'apple', 'mango', 'orange')
# <class 'tuple'>

# %%
j = ("banana","apple","mango","orange")

l = list(j)
l[2]="haha"
t=tuple(l)
t
# Out:
# ('banana', 'apple', 'haha', 'orange')

# %%
j = ("banana","apple","mango","orange")

j[2]="bbbbb"
print(j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 j = ("banana","apple","mango","orange")
# ----> 3 j[2]="bbbbb"
#       4 print(j)
#
# TypeError: 'tuple' object does not support item assignment

# %%
j = ("banana","apple","mango","orange")

print(j[2:])
# Out:
# ('mango', 'orange')

# %%
print(j[:3])
# Out:
# ('banana', 'apple', 'mango')

# %%
print(j[1:3])
# Out:
# ('apple', 'mango')

# %%
a =  ("banana","apple","mango","orange")

(aaaa,bbbb,cccc,dddd) = a

print(aaaa)
print(bbbb)
print(cccc)
print(dddd)
# Out:
# banana
# apple
# mango
# orange

# %%
a =  ("banana","apple","mango","grapes","orange")
(aa,bb,*cc,dd)=a

print(aa)
print(bb)
print(cc)
print(dd)
# Out:
# banana
# apple
# ['mango', 'grapes']
# orange

# %%
k=(1,32,5,870,90)
k1=(67,349)

print(k + k1)
# Out:
# (1, 32, 5, 870, 90, 67, 349)

# %%
a =  ("banana","apple","mango","grapes","orange")

l = list(a)
l.append("hhhhhh")
t=tuple(l)
print(t)
# Out:
# ('banana', 'apple', 'mango', 'grapes', 'orange', 'hhhhhh')

# %%
a =  ("banana","apple","mango","grapes","orange","mango")
j = a.index("mango")
print(j)
# Out:
# 2

# %%
d = a.count("mango")
s = a.count("apple")
print(d)
s
# Out:
# 2
# 1

# %%
a= ("a","b","c")
b= (1,2,3)

a+b
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
a =  ("banana","apple","mango","grapes","orange")

for j in a:
    print(j)
# Out:
# banana
# apple
# mango
# grapes
# orange

# %%
for j in range(len(a)):
    print(j)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for j in range(len(a)):
    print(a[j])
# Out:
# banana
# apple
# mango
# grapes
# orange
