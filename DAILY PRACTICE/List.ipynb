# %% [markdown]
# #  list

# %%
mylist = ["name","number",123,4.33]

print(mylist)
# Out:
# ['name', 'number', 123, 4.33]

# %%
mylist = ["name","number",123,4.33]  
print(len(mylist))
# Out:
# 4

# %%
mylist = ["name","number",123,4.33]      #list is mutable
mylist[1]="jklw"
print(mylist)
# Out:
# ['name', 'jklw', 123, 4.33]

# %%
mylist = ["name","number",123,123,4.33]  #list allow duplicates
print(mylist)
# Out:
# ['name', 'number', 123, 123, 4.33]

# %%
mylist = ["name","number",123,4.33]
print(mylist[0])
# Out:
# name

# %%
print(mylist[2])
# Out:
# 123

# %%
print(mylist[-1])
# Out:
# 4.33

# %%
print(mylist[-3])
# Out:
# number

# %%
list_1 = ["arul","yogesh","vinnu","tamil"]

for i,name in enumerate(list_1,start=1 ):
#    print(i,name)
    print(f"{i}) {name}")
# Out:
# 1) arul
# 2) yogesh
# 3) vinnu
# 4) tamil

# %%
a = [1,2,3,4,5,6]

for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
list_1 = ["name","number",123,4.33]

print(list_1[1:-1])
# Out:
# ['number', 123]

# %%
print(type(list_1))
# Out:
# <class 'list'>
