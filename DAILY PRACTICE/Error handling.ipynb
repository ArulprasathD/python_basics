# %%
try:
    num =int(input("Enter the number : "))

    print(10/num)

except:
    print("error occur")
# Out:
# Enter the number :  0
# error occur

# %%
try:
    num =int(input("Enter the number : "))

    k=(10/num)

except ZeroDivisionError:
    print("Cannot divide by zero")

except ValueError:
    print("Invalid input")

else:
    
    print("result",k)
# Out:
# Enter the number :  4
# result 2.5

# %%
def div(a,b):
   return a % b

try:
    a = int(input("Enter the number : "))
    b = int(input("Enter the number : "))

    j = div(a,b)
    print(j)

except ValueError : 
    print("Invalid input")
except ZeroDivisionError :
    print("Divided by zero")
# Out:
# Enter the number :  3
# Enter the number :  0
# Divided by zero

# %%
my_list = [10,20,30,40,50]

a = int(input("enter the index : "))

try:
    def indexx(my_list):
        x = my_list[a]
        return x

        result = index(my_list)
        print(x)

except IndexError:
    print("Index out of range")
# Out:
# enter the index :  3

# %%
def indexx(my_list):
        return my_list[a]


my_list = [10,20,30,40,50]

while True:
    try:
        a = int(input("Enter the index : "))

        k = indexx(my_list)
        print(k)
        break

    except IndexError:
        print("Total len is :",len(my_list),
          "\nIndex out of Range")
# Out:
# Enter the index :  10
# Total len is : 5
# Index out of Range
# Enter the index :  2
# 30
