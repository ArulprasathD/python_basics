# %%
"""
5️⃣ Conditional Statements 
Check even or odd. 
Check positive, negative or zero.
Find largest of 3 numbers. 
Grade calculator. 
Check leap year. 
Simple login system.
ATM withdraw logic.
Check voting eligibility. 
Nested if example. 
Use ternary operator. 
Check divisible by 5 and 3. 
Simple calculator using if-elif. 
Find smallest of 2 numbers. 
Temperature condition example. 
Check character is vowel or consonant.
"""

# %%
# 1 Check even or odd

a = int(input("check the number is even or odd,pls enter the number : ".title()))

if a % 2 == 0:
    print("Even")
else:
    print("odd")
# Out:
# Check The Number Is Even Or Odd,Pls Enter The Number :  2
# Even

# %%
#2 Check positive, negative or zero

a = int(input("Enter number : "))

if  a > 0:
    print("Positive")
elif a == 0:
    print("Zero")
else:
    print("Negative")
# Out:
# Enter number :  5
# Positive

# %%
#3 Find largest of 3 numbers

a = 23
b = 17
c = 100

if a >= b and a >= c:
    print(a, "is largest number")
elif b >= a and b >= c:
    print(b, "is largest number")
else:
    print(c,"is largest number")
# Out:
# 100 is largest number

# %%
#4 Grade calculator

mark = int(input("Enter the mark : "))

if mark < 0 or mark > 100:
    print("Invalid mark")
    if mark < 0:
        print("meet me")
elif  90 <= mark <= 100:
    print("A Grade , keep it up")
elif 80 <= mark <= 89:
    print("B Grade , good")
elif 70 <= mark <= 79:
    print("C Grade , average")
elif 60 <= mark <= 69:
    print("D Grade , not bad ")
elif 50 <= mark <= 59:
    print("E Grade , need more focus")
else:
    print("fail need to study")
# Out:
# Enter the mark :  88
# B Grade , good

# %%
#5 Check leap year


year = int(input("Enter the year : "))


if year % 400 == 0:
    print(f"{year} : Leap year")
elif year % 100 == 0:
    print(f"{year} : No Leap year")
elif year % 4 == 0:
    print(f"{year} : Leap year")
else:
    print(f"{year} : No Leap year")
# Out:
# Enter the year :  1980
# 1980 : Leap year

# %%
#6 Simple login system

userid = "zoho123@"
saved_password = "member243zoho"

if userid == "zoho123@":
    entered_password = (input("Enter the password : "))
    if entered_password == saved_password:
        print("Authentication successful")
    else:
        print("Authentication Denied")
else: 
    print("invalid user")


#or
#while loop

atm_pin = "3275"
enter_pin = ""

while enter_pin != atm_pin:               
    enter_pin = input("please Enter the correct pin: ")

print("Authentication successful ")
# Out:
# Enter the password :  memeber243zoho
# Authentication Denied
# please Enter the correct pin:  3275
# Authentication successful

# %%
#7 ATM withdraw logic

atm_pin = "3275"
attempt = 0

while attempt < 3:
    enter_pin = input("Enter your PIN: ")

    if enter_pin == atm_pin:
        print("Authentication successful")
        break
    else:
        attempt += 1
        print("Wrong PIN")

if attempt == 3:
    print("Your account is blocked")
# Out:
# Enter your PIN:  12
# Wrong PIN
# Enter your PIN:  33
# Wrong PIN
# Enter your PIN:  445
# Wrong PIN
# Your account is blocked

# %%
#8 Check voting eligibility

age = int(input("enter age : "))

voter_id = "yes"

if age < 18:
    print("you are not eligible")
elif age >=18:
    voteid = (input("you have voter id : (yes/no)").lower())          
    if voteid == voter_id:
        print("you are eligible")
    else:
        print("apply for voter id")
# Out:
# enter age :  33
# you have voter id : (yes/no) YES
# you are eligible

# %%
#9 Nested if example

age = int(input("Enter age: "))
monthly_salary = 25000

if age >= 22:
    salary = int(input("enter salary : "))
    if salary >= monthly_salary:
        print("you can send a loan request ")
    else:
        print("sry, you are not eligible")
else:
    print("not eligible")
# Out:
# Enter age:  22
# enter salary :  20000
# sry, you are not eligible

# %%
#10 Use ternary operator

age = int(input("enter age : "))

print("eligible") if age > 20 else print("not eligible")

print("------------------------------------------------------------")

#11 Check divisible by 5 and 3

num = int(input("enter the number : "))

output = "divisible" if num % 5 == 0 and num % 3 == 0 else "not divisible"
print(output)
# Out:
# enter age :  2
# not eligible
# ------------------------------------------------------------
# enter the number :  3
# not divisible

# %%
#12 Simple calculator using if-elif.

num1 = int(input("number 1 : "))
num2 = int(input("number 2 : "))
operator = input("{add | sub | mul | div or + | - | * | / } : ") .lower()

if "add" == operator or "+" == operator:
    print("add",num1+num2)

elif "sub" == operator or "-" == operator:
    print("sub",num1-num2)

elif "mul" == operator or "*" == operator:
    print("mul",num1*num2)
    
elif "div" == operator or "/" == operator:
    if num2 != 0:
        print("div",num1/num2)
    else:
        print("cannot divide by zero")
else:
    print("invalid operator")
# Out:
# number 1 :  2
# number 2 :  3
# {add | sub | mul | div or + | - | * | / } :  add
# add 5

# %%
#13 Find smallest of 2 numbers

num1 = int(input("enter num 1 : "))
num2 =int(input("enter num 2 : "))

if num1 < num2 :
    print(f"{num1} is small")
elif num2 == num1:
    print(f"both {num1} and {num2} are equal")
else:
    print(f"{num2} is small")
# Out:
# enter num 1 :  2
# enter num 2 :  3
# 2 is small

# %%
#14 Temperature condition example


temp = int(input("enter the current temperature level : "))


if temp > 40:
    print(f"{temp}°C current climate very hot")
elif 40 >= temp and  31 <= temp:
    print(f"{temp}°C current climate hot")
elif 30 >= temp and 21 <= temp:
    print(f"{temp}°C current climate normal")
elif 20 >= temp and 11 <= temp:
    print(f"{temp}°C current climate cold")
else:
    print(f"{temp}°C current climate very cold")
# Out:
# enter the current temperature level :  33
# 33°C current climate hot

# %%
char = input("Enter a single character: ").lower()
while True:
    if len(char) != 1:
        print("Please enter only one character")
    elif not char.isalpha():
        print("Please enter an alphabet letter")
elif char in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a single character:  qw
# Please enter only one character
