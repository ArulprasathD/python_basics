# %%
try:
    a = 10
    b = 20
    c = a + d
    print(c)
except:
    print("invalid")
# Out:
# invalid

# %%
def exa(a,b):
    try:
        a = int(input("Enter num :"))
        b = int(input("Enter num :"))
        c = a / b
        print(c)
    except:
        print("error")
exa(2,4)
# Out:
# Enter num : 3
# Enter num : 4
# 0.75

# %%
num = 10
