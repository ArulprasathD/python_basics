# %%
class myobject:
    x = 14
    y = 3 +4j

c=myobject()
c.x
# Out:
# 14

# %%
class myobject:
    def add(self):
        x = 12
        y = 16
        return x+y

c = myobject()
k=c.add()
print(k)
# Out:
# 28

# %%
class myobject:
    def add(hy,x,y):
        return x+y

j1 = myobject()
c1=j1.add(2,4)
print(c1)
# Out:
# 6
