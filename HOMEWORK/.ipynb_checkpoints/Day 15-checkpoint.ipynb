# %%
i = 103010

total = 0

while i > 0:
    val = i % 10
    if val == 0:
        total += 1
    i = i // 10

print("count : ",total)
# Out:
# count :  3

# %%
i = 583246

a = i

even = 0

while i > 0:
    val = i % 10
    if val % 2 == 0:
        even = even*10+val
        
    i = i // 10

rev = 0
while even > 0:
    rev = rev*10 + even%10
    even = even//10

print("evencount : ",rev)
# Out:
# evencount :  8246
