# %% [markdown]
# infosis--python 1 year xp..Chennai
#
# wipro..python ..fresher...coimb
#
# tcs...java..fres...chen
#
# cogni..java...1 year exp....bangalore..

# %% [markdown]
# # if conditions

# %%
"""
programming language = " python , java "

experience = " fresher - 1 year experince "

"""

language = input("Enter your preferred language : ").upper()

experience = int(input("Enter your years of experience : "))

location = input("Location (chennai/coimbatore/bangalore) : ")

print("-------employee data-------")
print(f"programming language :{language}")
print(f"years of experience  :{experience}")
print("----------------------------")

if (language == "PYTHON"  and 1 == experience and location == "chennai"):
    print("You are hired at Infosys!! 😃".title())
elif(language == "PYTHON" and 0 == experience and location == "coimbatore"):
    print("You are hired at wipro!! 😊".title())
elif(language == "JAVA" and 0 == experience and location == "chennai" ):
    print("You are hired at tcs!! 😃".title())
elif (language == "JAVA" and 1 == experience and location == "bangalore"):
    print("You are hired at Cognizant!! 😊".title())
else:
    print("your are not eligible!! 😓")
print("----------welcome----------".upper())
# Out:
# Enter your preferred language :  python
# Enter your years of experience :  0
# Location (chennai/coimbatore/bangalore) :  coimbatore
# -------employee data-------
# programming language :PYTHON
# years of experience  :0
# ----------------------------
# You Are Hired At Wipro!! 😊
# ----------WELCOME----------
