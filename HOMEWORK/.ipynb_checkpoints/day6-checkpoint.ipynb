# %%
gender=input("enter the gender: ").lower()
exp=int(input("enter the experience: "))
if gender == "male":
    if(exp == 1):
        print("tcs")
    elif(exp == 2):
        print("wibro")
    else:
        print("invalid")
elif gender == "female":
    if(exp == 2):
        print("tcs")
    elif(exp == 3):
        print("wibro")
    else:
        print("invalid")
        
else:
    print("invalid")
