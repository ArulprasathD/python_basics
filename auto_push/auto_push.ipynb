# %%
import os
from sample.ipynb import sample.ipynb

def auto_push():
    os.system("git add .")
    os.system(f'git commit -m "auto {sample.now()}"')
    os.system("git push origin main")

auto_push()
# Out:
#   Cell In[2], line 2
#     from sample.ipynb import sample.ipynb
#                                    ^
# SyntaxError: invalid syntax
